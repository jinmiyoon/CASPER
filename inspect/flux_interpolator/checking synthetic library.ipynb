# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'notebook')

# %%
synth=pkl.load(open("../../interface/libraries/MASTER_spec_interp.pkl", 'rb'))

# %%
wave = np.arange(3000, 5001, 1)

# %%
synth['GIANT'](4500, -2.5, 1.5)
# Out:
# array([0.99883559, 0.82418296, 0.7463209 , ..., 0.97819084, 0.96297291,
#        0.95233536])

# %%
np.size(synth['GIANT'](4500, -2.5, 1.5))
# Out:
# 2001

# %%
plt.plot(wave, synth['GIANT'](4250, -2.5, 1.5), lw=1)
plt.plot(wave, synth['DWARF'](4000, -4.5, 3.5), lw=1, color='purple')
plt.xlim(3800,5000)
plt.axhline(1.0, lw=1, color='r')
plt.axvline(4315, lw =1, color ='k')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
length =100
teff_irfm= 4500
teff_irfm_unc =250
gravity = "GIANT"
FEH = -2.5
CFE = 1.5
span = np.ones(length)
temp_values = np.random.normal(teff_irfm, teff_irfm_unc, length)

# %%
synth_array= synth[gravity](np.column_stack((temp_values, span * FEH, span * CFE)))

# %%
len(synth_array)
# Out:
# 100

# %%
synth_array[10]
# Out:
# array([0.99835276, 0.82247189, 0.74441331, ..., 0.97749997, 0.96206873,
#        0.95126366])

# %%
temp_values
# Out:
# array([4614.35462115, 4460.75124647, 4560.68170677, 4350.70666599,
#        4785.40884704, 3980.78005375, 4667.224339  , 4297.48224107,
#        4412.64883508, 4979.13506306, 4474.95756175, 4696.50328939,
#        4390.56906929, 4657.36494094, 4627.12750162, 4738.87598984,
#        4532.716769  , 4845.49691754, 4461.71752373, 4250.27294294,
#        4296.38989547, 4749.32426451, 4615.64837056, 4486.99513675,
#        4231.89801759, 4196.52093417, 4047.59167387, 4364.39613483,
#        4540.60621956, 4674.39172055, 4281.62550579, 4481.18305713,
#        4668.91068537, 4474.83137696, 4688.2232911 , 4880.9193487 ,
#        4744.73758734, 4587.48501251, 4638.84279546, 5072.5566897 ,
#        4303.13230106, 4717.59654084, 4640.00994468, 4332.11310507,
#        4528.08619801, 4514.16957069, 4491.33128719, 3891.09164444,
#        4574.42812306, 4555.39889018, 4635.39958273, 5083.82237057,
#        4426.56170617, 4243.60307724, 4615.38943212, 4347.65961171,
# ...
