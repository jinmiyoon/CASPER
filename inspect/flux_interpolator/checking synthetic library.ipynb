# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import scipy
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'notebook')
# %matplotlib notebook

# %%
import os
print(os.getcwd())
# Out:
# /Users/jyoon/GitHub/CASPER/inspect/flux_interpolator

# %%
#master_synth=pkl.load(open("../../interface/libraries/MASTER_spec_interp.pkl", 'rb'))
"""
path="../../interface/libraries/LinearNDInterp.pkl.gz"
import gzip
with gzip.open(path, "rb") as f:
    synth = pkl.load(f, encoding='bytes')
"""
path="/Users/jyoon/Documents/research/synthetic_library/building_casper_synth_flux/arch_libs/MASTER_spec_interp.pkl"

# %%
#synth([4500, 5.0, -4.5, 2.75])

# %%
master_synth=pkl.load(open(path, 'rb'))
master_synth

master_synth['GIANT']([4500, -4.5, 2.75])
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
wave = np.arange(3000, 5001, 1)

# %%
#%%
np.size(master_synth['GIANT'](4500, -4.5, 2.75))
# Out:
# 2001

# %%
#%%
plt.plot(wave, master_synth['GIANT'](4500, -4.5, 2.75), lw=1)
plt.plot(wave, master_synth['DWARF'](4500, -4.5, 2.75), lw=1, color='purple')
plt.xlim(3800,5000)
plt.axhline(1.0, lw=1, color='r')
plt.axvline(4315, lw =1, color ='k')
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
length =100
teff_irfm= 4500
teff_irfm_unc =250
gravity = "GIANT"
FEH = -2.5
CFE = 1.5
span = np.ones(length)
temp_values = np.random.normal(teff_irfm, teff_irfm_unc, length)

# %%
synth_array= synth[gravity](np.column_stack((temp_values, span * FEH, span * CFE)))

# %%
len(synth_array)

# %%
synth_array[10]

# %%
temp_values
