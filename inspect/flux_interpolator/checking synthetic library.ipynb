# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import scipy
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'notebook')
# %matplotlib notebook

# %%
import os
print(os.getcwd())
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity ='all'
# Out:
# /Users/jyoon/GitHub/CASPER/inspect/flux_interpolator

# %%
#master_synth=pkl.load(open("../../interface/libraries/MASTER_spec_interp.pkl", 'rb'))

# Devin's MASTER_spec_interp.pkl
path1="../../interface/libraries/MASTER_spec_interp.pkl"
with open(path1, "rb") as f_devin:
    devin_synth = pkl.load(f_devin)

path2="/Users/jyoon/Documents/research/synthetic_library/building_casper_synth_flux/arch_libs/MASTER_spec_interp.pkl"

with open(path2, "rb") as f_jinmi:
    jinmi_synth = pkl.load(f_jinmi)

# %%
#synth([4500, 5.0, -4.5, 2.75])

# %%
devin_synth['GIANT']([4500, -4.5, 2.75])
jinmi_synth['GIANT']([4500, -4.5, 2.75])
# Out:
# array([[0.9654493 , 0.90821901, 0.87649772, ..., 0.99838156, 0.99800414,
#         0.99505815]])
# array([[ 37132.21484375,  35057.03515625,  33786.23828125, ...,
#         597567.8125    , 597485.9375    , 597026.625     ]])

# %%
wave = np.arange(3000, 5001, 1)

# %%
grav_path = "/Users/jyoon/GitHub/CASPER/interface/libraries/grav_interp.pkl"
with open(grav_path, "rb") as f2:
    grav_interp = pkl.load(f2)
#f2.close()

logg_dwarf = grav_interp['DWARF']([4500, -4.5])[0]
logg_giant = grav_interp['GIANT']([4500, -4.5])[0]
print(logg_dwarf, logg_giant)
# Out:
# 5.0 0.7575919694014275

# %%
#%%
plt.plot(wave, master_synth['GIANT'](4500, -4.5, 2.75), lw=1)
plt.plot(wave, master_synth['DWARF'](4500, -4.5, 2.75), lw=1, color='purple')

plt.xlim(3800,5000)
plt.axhline(1.0, lw=1, color='r')
plt.axvline(4315, lw =1, color ='k')
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (3800.0, 5000.0)

# %%
#%%
plt.plot(wave,devin_synth['GIANT'](4500, -4.5, 2.75), lw=1)
plt.plot(wave, devin_synth['DWARF'](4500, -4.5, 2.75), lw=1, color='purple')

plt.xlim(3800,5000)
plt.axhline(1.0, lw=1, color='r')
plt.axvline(4315, lw =1, color ='k')
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (3800.0, 5000.0)

# %%
length =100
teff_irfm= 4500
teff_irfm_unc =250
gravity = "GIANT"
FEH = -2.5
CFE = 1.5
span = np.ones(length)
temp_values = np.random.normal(teff_irfm, teff_irfm_unc, length)

# %%
synth_array= synth[gravity](np.column_stack((temp_values, span * FEH, span * CFE)))

# %%
len(synth_array)

# %%
synth_array[10]

# %%
temp_values
