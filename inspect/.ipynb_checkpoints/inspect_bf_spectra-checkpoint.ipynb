# %%
import os, sys
#import interface_main, spectrum
from astropy.io import fits
#from collections import namedtuple
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
from ipywidgets import interact
import importlib

#import pandas as pd
#import EW
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
sys.path.insert(0,'../interface/')
import GISIC_C as GISIC

# %%
# Get the current working 
# directory (CWD) 
cwd = os.getcwd() 
      
# Print the current working 
# directory (CWD) 
print("Current working directory:", cwd)
# Out:
# Current working directory: /Users/jyoon/GitHub/CASPER/inspect

# %%
# %ls ../inputs/spectra/bf-full-survey-data/
# Out:
# Icon?                     jy1706_m1b_casper.fits    jy2866_m1b_casper.fits
# g77-61_blue_sum.fits      jy1706_m2b_casper.fits    jy2866_m2b_casper.fits
# g77-61_m1b_casper.fits    jy1894_m1b_casper.fits    jy3116_med_casper.fits
# g77-61_m2b_casper.fits    jy1894_m2b_casper.fits    jy3116_sum_casper.fits
# hd198269_m1b_casper.fits  jy1900_m1b_casper.fits    jy3193_m1b_casper.fits
# hd198269_m2b_casper.fits  jy1900_m2b_casper.fits    jy3193_m2b_casper.fits
# he0017_m1b_casper.fits    jy1926_m1b_casper.fits    jy3196_med_casper.fits
# jy0502_sum_casper.fits    jy1926_m2b_casper.fits    jy3196_sum_casper.fits
# jy0538_sum_casper.fits    jy2040_m1b_casper.fits    jy3233_sum_casper.fits
# jy0768_med_casper.fits    jy2183_m1b_casper.fits    jy3255_m1b_casper.fits
# jy0768_sum_casper.fits    jy2183_m2b_casper.fits    jy3255_m2b_casper.fits
# jy0909_m1b_casper.fits    jy2309_med_casper.fits    jy3291_m1b_casper.fits
# jy0909_m2b_casper.fits    jy2309_sum_casper.fits    jy3291_m2b_casper.fits
# jy1051_m1b_casper.fits    jy2552_m1b_casper.fits    jy3321_m1b_casper.fits
# jy1051_m2b_casper.fits    jy2552_m2b_casper.fits    jy3321_m2b_casper.fits
# jy1118_m1b_casper.fits    jy2553_m1b_casper.fits    smss1738_m1b_casper.fits
# jy1196_sum_casper.fits    jy2553_m2b_casper.fits    smss1738_m2b_casper.fits
# jy1390_m1b_casper.fits    jy2559_m1b_casper.fits
# jy1390_m2b_casper.fits    jy2559_m2b_casper.fits

# %%
# Changing the CWD 
#os.chdir('../')

# %%
spectra_path= "../inputs/spectra/bf-full-survey-data/"

# %%
star="jy2866"
star_m1b= star+"_m1b_casper.fits"
#star_m1b="smss1738_m1b_casper.fits"
star_m2b= star+"_m2b_casper.fits"
star_comb= star+"_blue_sum.fits"

# %%
spec1= fits.open(spectra_path+star_m1b)
spec2= fits.open(spectra_path+star_m1b)
#comb= fits.open(spectra_path+star_comb)

# %%
spec1.info()
# Out:
# Filename: ../inputs/spectra/bf-full-survey-data/jy2866_m1b_casper.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     287   (8192, 1, 4)   float32

# %%
spec1[0].header
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Unfixable error: Illegal keyword name '$EXPTIME' [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    3 / Number of axes
# NAXIS1  =                 8192 / Axis length
# NAXIS2  =                    1 / Axis length
# NAXIS3  =                    4 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2017-03-07T21:45:35' / Date FITS file was generated
# IRAF-TLM= '2017-03-23T18:34:41' / Time of last modification
# OBJECT  = 'jy2866  '           / Name of the object observed
# BUNIT   = 'ADU     '               / units of physical values (LBT)
# COMMENT  Detector Information
# DETECTOR= 'e2v CCD231-68 Blue CCD 1'     / Detector name
# DETSIZE = '[1:8288,1:3088]'       / Unbinned size of detector full array
# NAMPS   =                    4 / Number of amplifiers in the detector
# GAINDL  =                    3 / Pixel integration time, in sequencer clocks
# PIXITIME=            1.2000E-6 / Pixel integration time, in seconds
# CCDXBIN =                    1 / CCD X-axis Binning Factor
# CCDYBIN =                    1 / CCD Y-axis Binning Factor
# OVERSCNX=                    0 /
# OVERSCNY=                    0 /
# READOUT = 'ARLBRL  '           / Amplifiers used in readout
# PIXSCALE=                0.120 / Unbinned pixel scale [arcsec per pixel]
# PIXSIZE =                 15.0 / Unbinned pixel size [microns]
# CCDROI  = '[1:8288,1:3088]'    /
# COMMENT  Observatory Information
# OBSERVAT= 'MGIO-LBT'           / Observatory Site
# TELESCOP= 'LBT-SX  '           / Telescope and Focus
# FOCSCALE=                 1.67 / Focal Plane Scale [arcsec per mm]
# LATITUDE=             32.70131 / Site Latitude [deg N]
# LONGITUD=            109.88906 / Site Longitude [deg W]
# ELEVATIO=               3221.0 / Site Elevation [meters]
# OBSERVER= 'Fausnaugh, Johnson' / Observer(s)
# PARTNER = 'OSURC   '           / LBT Project Partner(s)
# PROPID  = 'ND_carbon'          / Observing Proposal ID
# PI_NAME = 'beers   '           / Project PI Name(s)
# SUPPORT = 'Barry Rothberg'     / LBT Support Scientist(s)
# TELOPS  = 'Steve Allanson'     / LBT Telescope Operator(s)
# COMMENT  Exposure Information
# GROUP   =                    0 / Group identifier for related images
# IMAGETYP= 'OBJECT  '           / Type of observation
# EXPTIME =                 2500 / Exposure time [seconds]
# DARKTIME=               503.51 / Cumulative Dark Time [seconds]
# LEDFLASH=            0.0000E+0 / Time to flash lab LEDs [seconds]
# FILENAME= 'mods1b.20161118.0018' / Filename assigned by the data-taking system
# UNIQNAME= '161114M8.00v'       / Unique filename; if filename is invalid
# ACQTAG  = 'MODS1B.20161118073403' / Unique Acquisition ID Tag
# COMMENT  Instrument Configuration
# INSTRUME= 'MODS1B  '           / Instrument Name
# HATCH   = 'OPEN    '           / Instrument Dark Hatch
# CALIB   = 'OUT     '           / Calibration Tower Position
# CALLAMPS= 'None    '           / Calibration Lamps
# VFLAT   =                  4.0 / Variable Intensity Flat Lamp Intensity
# SLITMASK=                    5 / Slit Mask Cassette position
# MASKPOS = 'IN      '           / Slit Mask Position
# MASKNAME= 'LS5x60x0.6'         / Slit Mask Name
# MASKINFO= '0.6 arcsec Segmented Long Slit' / Slit Mask Description
# DICHROIC=                    2 / Dichroic Turret Position
# DICHNAME= 'Dual    '           / Dichroic Beam Selector position ID
# DICHINFO= 'CSIRO 575nm Dichroic Nr1' / Dichroic Beam Selector Description
# COMMENT  Spectrograph Channel Configuration
# CHANNEL = 'BLUE    '           / Channel name, Blue or Red
# COLFOCUS=                18301 / Collimator Focus (A+B+C) [microns]
# COLTTFA =                16960 / Collimator TTF actuator A [microns]
# COLTTFB =                17925 / Collimator TTF actuator B [microns]
# COLTTFC =                20017 / Collimator TTF actuator C [microns]
# GRATING =                    2 / Grating Turret Position
# GRATNAME= 'G400L   '           / Name of the Disperser at GRATING
# GRATINFO= '400l/mm Blue Grating RGL MR162-2-7-1' / Description of the Disperser
# GRATTILT=                19884 / Grating Tilt [microns]
# GRCENLAM= '        '           / Grating nominal central wavelength [Ang]
# GRORDER =                    0 / Grating order used
# FILTER  =                    1 / Camera Filter Wheel Position
# FILTNAME= 'Clear   '           / Camera Filter Name
# FILTINFO= 'Fused Silica Clear 128x86x6mm Nr1' / Camera Filter Description
# CAMFOCUS=                 3330 / Camera Primary Mirror Focus [microns]
# COMMENT  IMCS IR Reference Laser Status
# IRLASER = 'ON      '           / IMCS IR Laser AC Power On or Off
# IRBEAM  = 'ENABLED '           / IMCS IR Laser Beam Enabled or Disabled
# IRPSET  =                  1.0 / IMCS IR Laser Beam Power Set Point [mW]
# IRPOUT  =                  1.1 / IMCS IR Laser Beam Power Output [mW]
# IRTEMP  =                 25.4 / IMCS IR Laser Head Temperature [deg C]
# IRTSET  =                 25.5 / IMCS IR Laser Head Temp Set Point [deg C]
# COMMENT  Target and Guide Star Coordinates
# OBJNAME = 'jy2866  '           / Target Name
# OBJRA   = '01:55:49.53'        / Target RA
# OBJDEC  = '+00:49:38.96'       / Target DEC
# OBJRADEC= 'FK5'                / Target Coordinate System
# OBJEQUIN= 'J2000'              / Target Coordinate System Equinox
# OBJPMRA =                 0.00 / Target RA proper motion [mas per yr]
# OBJPMDEC=                 0.00 / Target Dec proper motion [mas per yr]
# OBJEPOCH=              2000.00 / Target Epoch
# GUINAME = 'NOMAD1-0908-0020637' / Guide Star Name
# GUIRA   = '01:55:40.10'        / Guide Star RA
# GUIDEC  = '+00:49:41.52'       / Guide Star DEC
# GUIRADEC= 'FK5'                / Guide Star Coordinate System
# GUIEQUIN= 'J2000'              / Guide Star Coord System Equinox
# GUIPMRA =                 0.00 / Guide Star RA proper motion [mas per yr]
# GUIPMDEC=                 0.00 / Guide Star Dec proper motion [mas per yr]
# GUIEPOCH=              2000.00 / Guide Star Epoch
# COMMENT  Telescope and TCS Information
# TCSLINK = 'Live    '           / TCS Communications Link Status
# DATE-OBS= '2016-11-18T07:34:21.114' / UTC Date at start of obs
# UTC-OBS = '07:34:21.114'       / UTC Time at start of obs
# TIMESYS = 'UTC     '           / Time System
# LST-OBS = '04:05:55.049'       / Local Siderial Time at start of obs
# MJD-OBS =         57710.315522 / Modified JD=JD-2400000.5 at start of obs
# RADECSYS= 'FK5     '           / Coordinate System
# EQUINOX =               2000.0 / Equinox of coordinates
# TELRA   = '01:55:49.534'       / Telescope RA
# TELDEC  = '00:49:38.951'       / Telescope DEC
# POSANGLE=             35.00000 / Instrument Celestial Position Angle [deg]
# TELALT  =             46.04815 / Telescope Altitude at start of obs [deg]
# TELAZ   =            230.20154 / Telescope Azimuth at start of obs [deg]
# PARANGLE=             40.48311 / Parallactic Angle at start of obs [deg]
# ROTANGLE=           -147.03930 / Rotator Angle at start of obs [deg]
# ROTMODE = 'POSITION'           / Rotator Mode
# HA      = '02:10:33.935'       / Hour Angle at start of obs
# ZD      =                43.95 / Zenith Distance at start of obs [deg]
# AIRMASS =                 1.39 / Airmass (secZD) at start of obs
# COMMENT  Acquisition Guide and WFS System Configuration
# AGWXGP  =              -68.021 / AGW Guide Probe X focal plane position [mm]
# AGWYGP  =              -40.796 / AGW Guide Probe Y focal plane position [mm]
# AGWFOCUS=                0.000 / AGW Guide Probe relative focus [mm]
# AGWFILT =                    1 / Guide Camera Filter Wheel position
# AGWFNAME= 'Clear   '           / Guide Camera Filter Name
# AGWFINFO= 'Edmund Clear FuSi 50x5mm' / Guide Camera Filter Description
# AGWXS   =               21.559 / AGW Stage X actuator position [mm]
# AGWYS   =              160.811 / AGW Stage Y actuator position [mm]
# AGWFS   =               41.486 / AGW Stage Focus actuator position [mm]
# AGWFS0  =               38.500 / AGW Stage Focus Zero Point [mm]
# AGWXWFS =              -68.021 / AGW WFS Pickoff X focal plane position [mm]
# AGWYWFS =              -40.796 / AGW WFS Pickoff Y focal plane position [mm]
# COMMENT  GCS and PCS Guide Probe and Guide Star Data
# GPREQ_X =               68.140 / GCS Requested guide probe PCS X [mm]
# GPREQ_Y =              -41.010 / GCS Requested guide probe PCS Y [mm]
# GPACT_X =               68.141 / GCS Actual guide probe PCS X [mm]
# GPACT_Y =              -41.010 / GCS Actual guide probe PCX Y [mm]
# GSPRED_X=               68.141 / PCS Predicted guide star X position [mm]
# GSPRED_Y=              -41.011 / PCS Predicted guide star Y position [mm]
# GSMEAS_X=                0.000 / GCS Measured guide star X position [mm]
# GSMEAS_Y=                0.000 / GCS Measured guide star Y position [mm]
# GSDELTAX=               -0.324 / GCS cumulative X guide update position [mm]
# GSDELTAY=               -0.445 / GCS cumulative Y guide update position [mm]
# COMMENT  Blue CCD Head Electronics Box Sensor Data
# HSTEMP  =                 5.48 / HEB Post Heat Sink Air Temperature [deg C]
# CTEMPIN =                 2.77 / HEB Coolant Input Temperature [deg C]
# CTEMPOUT=                 4.15 / HEB Coolant Output Temperature [deg C]
# TEDPOWER= 'ON      '           / HEB Thermoelectric Device Power State
# LEDPOWER= 'OFF     '           / HEB External LED Power State
# IGPOWER = 'ON      '           / Dewar Vacuum Ion Gauge Power State
# HEB3V   =                 3.31 / HEB +3V Power Supply [VDC]
# HEBFANV =                11.85 / HEB Fan Power Supply [VDC]
# HEB15V  =               -15.04 / HEB -15V Power Supply [VDC]
# HEB5V   =                 4.93 / HEB +5V Power Supply [VDC]
# HEB24V  =                23.13 / HEB +24V Power Supply [VDC]
# BOGHTRV =                 1.86 / Dewar boil-off gas heater voltage
# COMMENT  Instrument Temperature Sensor Data
# AMBTEMP =                  4.4 / Outside Ambient Air Temperature [deg C]
# TAIRTOP =                  1.2 / MODS Inside Air Temp at Top [deg C]
# TAIRBOT =                  1.9 / MODS Inside Air Temp at Bottom [deg C]
# TCOLLTOP=                  2.0 / Collimator Truss Tube Top Temp [deg C]
# TCOLLBOT=                 -1.0 / Collimator Truss Tube Bottom Temp [deg C]
# IEBTEMPB=                 12.8 / Blue IEB Air Temperature [deg C]
# IEBGRT_B=                  1.9 / Blue IEB Glycol Return Temperature [deg C]
# IEBTEMPR=                  5.0 / Red IEB Air Temperature [deg C]
# IEBGRT_R=                  1.8 / Red IEB Glycol Return Temperature [deg C]
# IUBTAIR =                  7.3 / Utility Box Air Temperature [deg C]
# AGHSTEMP=                  2.2 / AGw Controller Heat Sink Temp [deg C]
# COMMENT  Instrument Glycol Cooling In-Line Sensor Data
# GSPRES  =                 38.5 / Glycol Supply Pressure [psi-g]
# GSTEMP  =                  2.0 / Glycol Supply Temperature [deg C]
# GRPRES  =                 37.0 / Glycol Return Pressure [psi-g]
# GRTEMP  =                  2.8 / Glycol Return Temperature [deg C]
# COMMENT  LBT Telescope Collimation State
# M1POSX  =               -0.077 / Primary Mirror X Position [mm]
# M1POSY  =               -0.537 / Primary Mirror Y Position [mm]
# M1POSZ  =               -0.048 / Primary Mirror Z Position [mm]
# M1ROTX  =               13.960 / Primary Mirror RX Rotation [arcsec]
# M1ROTY  =              -11.928 / Primary Mirror RY Rotation [arcsec]
# M1ROTZ  =                0.002 / Primary Mirror RZ Rotation [arcsec]
# M1CTEMP =                 1.55 / Primary Mirror Temperature [deg C]
# M1ATEMP =                 2.71 / Primary Mirror Ambient Air Temp [deg C]
# M2POSX  =               -2.553 / Secondary Mirror X Position [mm]
# M2POSY  =                0.527 / Secondary Mirror Y Position [mm]
# M2POSZ  =                2.276 / Secondary Mirror Z Position [mm]
# M2ROTX  =               64.044 / Secondary Mirror RX Rotation [arcsec]
# M2ROTY  =             -284.469 / Secondary Mirror RY Rotation [arcsec]
# M2ROTZ  =                0.015 / Secondary Mirror RZ Rotation [arcsec]
# M2CTEMP =                 1.55 / Secondary Mirror Temperature [deg C]
# COMMENT  LBT Telescope Temperature Sensor Data
# TTEMP201=                1.842 / Channel 201 Temperature [deg C]
# TTEMP202=                2.616 / Channel 202 Temperature [deg C]
# TTEMP203=                1.728 / Channel 203 Temperature [deg C]
# TTEMP204=                2.542 / Channel 204 Temperature [deg C]
# TTEMP205=                1.610 / Channel 205 Temperature [deg C]
# TTEMP206=                2.630 / Channel 206 Temperature [deg C]
# TTEMP207=                2.136 / Channel 207 Temperature [deg C]
# TTEMP208=                2.481 / Channel 208 Temperature [deg C]
# TTEMP209=                1.864 / Channel 209 Temperature [deg C]
# TTEMP210=                2.422 / Channel 210 Temperature [deg C]
# TTEMP301=                1.549 / Channel 301 Temperature [deg C]
# TTEMP302=                1.536 / Channel 302 Temperature [deg C]
# TTEMP303=                2.117 / Channel 303 Temperature [deg C]
# TTEMP304=                3.023 / Channel 304 Temperature [deg C]
# TTEMP305=                2.190 / Channel 305 Temperature [deg C]
# TTEMP306=                2.374 / Channel 306 Temperature [deg C]
# TTEMP307=                2.131 / Channel 307 Temperature [deg C]
# TTEMP308=                2.176 / Channel 308 Temperature [deg C]
# TTEMP309=                2.217 / Channel 309 Temperature [deg C]
# TTEMP310=                2.131 / Channel 310 Temperature [deg C]
# COMMENT  LBT Weather Station Information
# LBTWLINK= 'Up      '           / LBT Weather Station Link State
# LBTPRES =               689.20 / LBT Ambient Pressure [hPa]
# LBTTEMP =                 2.60 / LBT Ambient Temperature [deg C]
# LBTHUM  =                 5.40 / LBT Relative Humidity [percent]
# LBTDWPT =               -32.70 / LBT Dew Point [deg C]
# COMMENT  Miscellaneous Engineering Parameters
# LDGROT  =            212.96059 / Left Direct Gregorian Rotator Angle [deg]
# COMMENT
# R       = '13.9    '           /
# BIASPROC= 'biasSingle'         / Overscan subtracted by modsProc.py
# BIASQ1E =                306.0 / Bias subtracted from Q1E
# BIASQ1O =                318.0 / Bias subtracted from Q1O
# BIASQ2E =                355.5 / Bias subtracted from Q2E
# BIASQ2O =                359.0 / Bias subtracted from Q2O
# BIASQ3E =                279.0 / Bias subtracted from Q3E
# BIASQ3O =                302.0 / Bias subtracted from Q3O
# BIASQ4E =                324.0 / Bias subtracted from Q4E
# BIASQ4O =                308.5 / Bias subtracted from Q4O
# FLATPROC= '../flats/bpixFlat.fits' / Flat field image
# BPLFILE = '/usr/local/LBT/modsCCDRed/database/mods1b.bpl'
# BPWIDTH =                    5 / Bad pixel averaging region width [pixels]
# HISTORY modsProc v2.0.4 2016-03-08
# HISTORY modsProc - divided by flat field
# HISTORY modsProc - fixing bad pixels
# HISTORY modsAdd v2.0.2 2016-03-08 nfiles=5
# $EXPTIME=                 2500
# BANDID1 = 'spectrum - background fit, weights variance, clean no'
# BANDID2 = 'raw - background fit, weights none, clean no'
# BANDID3 = 'background - background fit'
# BANDID4 = 'sigma - background fit, weights variance, clean no'
# APNUM1  = '1 1 1710.23 1740.49'
# WCSDIM  =                    3
# CTYPE1  = 'LINEAR  '
# CTYPE2  = 'LINEAR  '
# CTYPE3  = 'LINEAR  '
# CRVAL1  =      2106.8346144802
# CRPIX1  =                   1.
# CD1_1   =    0.537492643613461
# CD2_2   =                   1.
# CD3_3   =                   1.
# LTM1_1  =                   1.
# LTM2_2  =                   1.
# LTM3_3  =                   1.
# WAT0_001= 'system=equispec'
# WAT1_001= 'wtype=linear label=Wavelength units=angstroms'
# WAT2_001= 'wtype=linear'
# WAT3_001= 'wtype=linear'
# DC-FLAG =                    0
# DCLOG1  = 'REFSPEC1 = argon_m1b_otf.ms.fits'

# %%
spec1[0].data[0]
# Out:
# array([[-5365.9966  , -1889.0786  ,   376.28604 , ...,    43.084465,
#            98.58553 ,   188.69118 ]], dtype=float32)

# %%
spec1[0].data.dtype
# Out:
# dtype('>f4')

# %%
spec1[0].data[0].shape
# Out:
# (1, 8192)

# %%
spec1[0].data[:,:,3]
# Out:
# array([[117.96414 ],
#        [ 82.28863 ],
#        [142.74612 ],
#        [  5.311016]], dtype=float32)

# %%
spec1[0].header['CRVAL1']
spec1[0].header['CD1_1']
# Out:
# 2106.8346144802
# 0.537492643613461

# %%
wave1_unc = (np.arange(0, spec1[0].header['NAXIS1'], 1) * spec1[0].header['CD1_1']) + spec1[0].header['CRVAL1']
flux1 =  spec1[0].data[0].flatten()

# %%
rv1 =  18.4 # jy2866
#rv1 =  -10.4 # G77-61

#rv1 = 70 # smss1738
        # Later, I would use astropy constant for speed of light, Sep 02 2020, J. Yoon
wave1 = wave1_unc/((rv1/2.99792e5) + 1)

# %%
print(wave1_unc[3000], wave1[3000])
# Out:
# 3719.312545320583 3719.084283222824

# %%
wave_int= wave1[np.where((wave1>3880) &( wave1<4830))]
flux_int= flux1[np.where((wave1>3880) &( wave1<4830))]

# %%
plt.plot(wave1, flux1, lw =0.5)
plt.axvline(4320, lw= 0.5,color ='r')
#plt.xlim(4200, 4400)
plt.minorticks_on()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
importlib.reload(GISIC)
# Out:
# <module 'GISIC_C' from '../interface/GISIC_C/__init__.py'>

# %%
wave1, norm_flux1, continuum1 = GISIC.normalize(wave1, flux1, sigma=30, k=1, 
                                                cahk=True,band_check=True, boost=True)
wave1, norm_flux2, continuum2 = GISIC.normalize(wave1, flux1, sigma=30, k=1, 
                                                cahk=True,band_check=True, boost=False)
# Out:
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False

# %%
plt.plot(wave1, flux1, lw=0.5)
plt.plot(wave1, norm_flux1, lw=0.5)
plt.plot(wave1, norm_flux2, lw=0.5)
plt.plot(wave1, continuum1, lw=0.5, color='k')
plt.plot(wave1, continuum2, lw=0.5, color='g')
plt.axvline(4320, color ='r', lw=0.5)

plt.minorticks_on()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
wave_cut, norm_flux_cut, continuum_cut = GISIC.normalize(wave_int, flux_int, sigma=30,k=1, s=12, cahk=True, 
                                                         band_check=True, flux_min=60, boost=True)
wave_cut, norm_flux_cut2, continuum_cut2 = GISIC.normalize(wave_int, flux_int, sigma=30,k=1, s=12, cahk=True, 
                                                         band_check=True, flux_min=70, boost=True)
wave_cut, norm_flux_cut3, continuum_cut3 = GISIC.normalize(wave_int, flux_int, sigma=30,k=1, s=12, cahk=True, 
                                                         band_check=True, flux_min=80, boost=True)
# Out:
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False

# %%
plt.plot(wave_int, flux_int)
plt.plot(wave_cut, continuum_cut, lw=0.5, color='k')
plt.plot(wave_cut, continuum_cut2, lw=0.5, color='g')
plt.plot(wave_cut, continuum_cut3, lw=0.5, color='r')
plt.axvline(3933, color ='r', lw=0.5)
plt.axvline(3968, color ='r', lw=0.5)
plt.axvline(4320, color ='r', lw=0.5)

plt.minorticks_on()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(wave_cut, norm_flux_cut, 'k-', lw=0.5)
plt.plot(wave_cut, norm_flux_cut2, 'g-',lw=0.5, label='best fit: k=1, flux_min=70, sigma=30')
plt.plot(wave_cut, norm_flux_cut3,'r-', lw=0.5)
plt.axvline(3933, color ='r', lw=0.5)
plt.axvline(3968, color ='r', lw=0.5)
plt.axvline(4320, color ='r', lw=0.5)
plt.axhline (1)
plt.legend(loc=1)
plt.minorticks_on()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
wave_cut, norm_flux_cut, continuum_cut = GISIC.normalize(wave_int, flux_int, sigma=30,k=1, s=12, cahk=True, 
                                                         band_check=True, flux_min=70, boost=True)
wave_cut, norm_flux_cut2, continuum_cut2 = GISIC.normalize(wave_int, flux_int, sigma=40,k=1, s=12, cahk=True, 
                                                         band_check=True, flux_min=70, boost=True)
wave_cut, norm_flux_cut3, continuum_cut3 = GISIC.normalize(wave_int, flux_int, sigma=50,k=1, s=12, cahk=True, 
                                                         band_check=True, flux_min=70, boost=True)
# Out:
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# 	adding CaII H&K continuum points
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# GISIC test False
# 	adding CaII H&K continuum points

# %%
plt.plot(wave_int, flux_int)
plt.plot(wave_cut, continuum_cut, lw=0.5, color='k', label='best fit: k=1, flux_min=70, sigma=30')
plt.plot(wave_cut, continuum_cut2, lw=0.5, color='g')
plt.plot(wave_cut, continuum_cut3, lw=0.5, color='r')
plt.axvline(3933, color ='r', lw=0.5)
plt.axvline(3968, color ='r', lw=0.5)
plt.axvline(4320, color ='r', lw=0.5)
plt.legend()
plt.minorticks_on()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(wave_cut, norm_flux_cut, 'k-', lw=0.5,label='best fit: k=1, flux_min=70, sigma=30')
plt.plot(wave_cut, norm_flux_cut2, 'g-',lw=0.5)
plt.plot(wave_cut, norm_flux_cut3,'r-', lw=0.5)
plt.axvline(3933, color ='r', lw=0.5)
plt.axvline(3968, color ='r', lw=0.5)
plt.axvline(4320, color ='r', lw=0.5)
plt.axhline (1)
plt.legend(loc=1)
plt.minorticks_on()

# %%
wave_cut, norm_flux_cut, continuum_cut = GISIC.normalize(wave_int, flux_int, sigma=30,k=1, s=12, cahk=True, 
                                                         band_check=False, flux_min=70, boost=True)
wave_cut, norm_flux_cut2, continuum_cut2 = GISIC.normalize(wave_int, flux_int, sigma=30,k=1, s=12, cahk=True, 
                                                         band_check=False, flux_min=70, boost=False)

# %%
plt.plot(wave_int, flux_int)
plt.plot(wave_cut, continuum_cut, lw=0.5, color='k', label='best fit: k=1, flux_min=70, sigma=30, boost=True')
plt.plot(wave_cut, continuum_cut2, lw=0.5, color='g',label='          k=1, flux_min=70, sigma=30, boost=False')
plt.axvline(3933, color ='r', lw=0.5)
plt.axvline(3968, color ='r', lw=0.5)
plt.axvline(4320, color ='r', lw=0.5)
plt.legend()
plt.minorticks_on()
